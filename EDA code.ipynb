# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('data_clean[1].csv')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (158, 10)

# %%
dataset.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
dataset['Month']=pd.to_numeric(dataset['Month'],errors='coerce')

# %%
dataset['Temp C']=pd.to_numeric(dataset['Temp C'],errors='coerce')

# %%
dataset['Weather']=dataset['Weather'].astype('category')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %%
dataset[dataset.duplicated()].shape
# Out:
# (0, 10)

# %%
dataset1=dataset.drop('Temp C',axis=1)

# %%
dataset1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0    118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...      ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
dataset2=dataset1.rename({'Solar.R':'Solar'},axis=1)

# %%
dataset2
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0  118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0  313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN    NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...    ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN  145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0  191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
dataset2['Ozone'].hist()
# Out:
# <Axes: >

# %%
data=dataset2.dropna()

# %%
data1=data.Ozone

# %%
box=plt.boxplot(data1)

# %%
[item.get_ydata() for item in box ['fliers']]
# Out:
# [array([135., 168.])]

# %%
[item.get_ydata()[1] for item in box ['whiskers']]
# Out:
# [1.0, 122.0]

# %%
dataset2['Ozone'].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
dataset['Weather'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
cols=dataset2.columns

# %%
colours=['#000099','#ffff00']

# %%
sns.heatmap(dataset2[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
dataset2[dataset2.isnull().any(axis=1)]
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4             5    NaN    NaN  14.3    5.0    5  2010    56       S
# 5             6   28.0    NaN  14.9    5.0    6  2010    66       C
# 9            10    NaN  194.0   8.6    5.0   10  2010    69       S
# 10           11    7.0    NaN   6.9    5.0   11  2010    74       C
# 23           24   32.0   92.0  12.0    NaN   24  2010    61       C
# 24           25    NaN   66.0  16.6    5.0   25  2010    57      PS
# 25           26    NaN  266.0  14.9    5.0   26  2010    58       C
# 26           27    NaN    NaN   8.0    5.0   27  2010    57      PS
# 31           32    NaN  286.0   8.6    6.0    1  2010    78       S
# 32           33    NaN  287.0   9.7    6.0    2  2010    74       C
# 33           34    NaN  242.0  16.1    6.0    3  2010    67      PS
# 34           35    NaN  186.0   9.2    6.0    4  2010    84       C
# 35           36    NaN  220.0   8.6    6.0    5  2010    85      PS
# ...

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Month          1
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
mean=dataset2['Ozone'].mean()

# %%
print(mean)
# Out:
# 41.583333333333336

# %%
dataset2['Ozone']=dataset2['Ozone'].fillna(mean)

# %%
dataset2.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
dataset2
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
obj=dataset2[['Weather']]

# %%
obj.isnull().sum()

# %%
obj=obj.fillna(obj.mode().iloc[0])

# %%
obj.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
dataset3=pd.concat([dataset2,obj],axis=1)

# %%
dataset3.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       3
# Weather       0
# dtype: int64

# %%
dataset3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather  \
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# ...

# %%
sns.pairplot(dataset2)

# %%
dataset2.corr()
# Out:
# C:\Users\RANI\AppData\Local\Temp\ipykernel_15764\1348899894.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset2.corr()
#             Unnamed: 0     Ozone     Solar      Wind     Month       Day  \
# Unnamed: 0    1.000000  0.111910 -0.109520 -0.158309  0.949690  0.216219
# Ozone         0.111910  1.000000  0.307253 -0.523806  0.123962 -0.030241
# Solar        -0.109520  0.307253  1.000000 -0.056594 -0.092918 -0.154212
# Wind         -0.158309 -0.523806 -0.056594  1.000000 -0.153507  0.040151
# Month         0.949690  0.123962 -0.092918 -0.153507  1.000000  0.061236
# Day           0.216219 -0.030241 -0.154212  0.040151  0.061236  1.000000
# Year               NaN       NaN       NaN       NaN       NaN       NaN
# Temp          0.337537  0.606275  0.273322 -0.441247  0.393321 -0.124538
#
# ...

# %%
dataset3=pd.get_dummies(data,columns=['Weather'])

# %%
dataset3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp  Weather_C  \
# 0             1   41.0  190.0   7.4    5.0    1  2010    67          0
# 1             2   36.0  118.0   8.0    5.0    2  2010    72          1
# 2             3   12.0  149.0  12.6    5.0    3  2010    74          0
# 3             4   18.0  313.0  11.5    5.0    4  2010    62          0
# 6             7   23.0  299.0   8.6    5.0    7  2010    65          0
# ..          ...    ...    ...   ...    ...  ...   ...   ...        ...
# 152         153   20.0  223.0  11.5    9.0   30  2010    68          0
# 153         154   41.0  190.0   7.4    5.0    1  2010    67          1
# 154         155   30.0  193.0   6.9    9.0   26  2010    70          0
# 156         157   14.0  191.0  14.3    9.0   28  2010    75          0
# 157         158   18.0  131.0   8.0    9.0   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0             0          1
# 1             0          0
# 2             1          0
# ...

# %%
dataset3=dataset3.dropna()

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
dataset3.values
# Out:
# array([[  1.,  41., 190., ...,   0.,   0.,   1.],
#        [  2.,  36., 118., ...,   1.,   0.,   0.],
#        [  3.,  12., 149., ...,   0.,   1.,   0.],
#        ...,
#        [155.,  30., 193., ...,   0.,   1.,   0.],
#        [157.,  14., 191., ...,   0.,   0.,   1.],
#        [158.,  18., 131., ...,   1.,   0.,   0.]])

# %%
arry=dataset3.values

# %%
scaler=MinMaxScaler(feature_range=(0,1))

# %%
rescaledx=scaler.fit_transform(arry)

# %%
set_printoptions(precision=2)

# %%
print(rescaledx[0:5,:])
# Out:
# [[0.   0.24 0.56 0.28 0.   0.   0.   0.25 0.   0.   1.  ]
#  [0.01 0.21 0.34 0.31 0.   0.03 0.   0.38 1.   0.   0.  ]
#  [0.01 0.07 0.43 0.56 0.   0.07 0.   0.43 0.   1.   0.  ]
#  [0.02 0.1  0.94 0.5  0.   0.1  0.   0.12 0.   0.   1.  ]
#  [0.04 0.13 0.89 0.34 0.   0.2  0.   0.2  0.   1.   0.  ]]
